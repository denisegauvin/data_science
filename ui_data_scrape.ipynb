# %% [markdown]
# Scraping Awwwards for tags on websites of the year
#
# Next steps:
# 1. Extract tags from raw html
# 2. Create function to
#     1. extract url from raw html
#     2. assign url to variable
#     3. insert variable in function to scrape destination page for colours and image
# 3. Analyze
# 4. Repeat for past years
# 5. Predict future trends

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request
import csv

# %%
urlpage='https://www.awwwards.com/websites/sites_of_the_year/'

# %%
page = urllib.request.urlopen(urlpage)

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin-when-cross-origin" name="referrer">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Sites Of The Year on Awwwards, the awards that recognize the talent and effort of the best web designers, developers and agencies in the world." name="description"/>
# <link href="https://www.awwwards.com/websites/sites_of_the_year/" rel="canonical"/>
# <meta content="#3ea094" name="theme-color"/>
# <meta content="Awwwards are the Website Awards that recognize and promote the talent and effort of the best developers, designers and web agencies in the world." name="Keywords"/>
# <title>    Sites Of The Year
# </title>
# <link href="https://www.awwwards.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.awwwards.com/manifest.json" rel="manifest"/>
# <style>
# ...

# %%
data = soup.find_all('li', class_='col-3 js-collectable')

# %%
print(data)
# Out:
# [<li class="col-3 js-collectable" data-model='{"likes":234,"id":34838,"images":{"thumbnail":"submissions\/2018\/11\/5bf2fbeb71b64.png"},"slug":"orano","title":"Orano","createdAt":1543190400,"tags":["Business &amp; Corporate","Web &amp; Interactive","Parallax","Unusual Navigation","Black","White","Yellow","Transitions","Experimental","Storytelling","Three.js","3D","UI design"],"type":"submission"}'>
# <div class="box-item">
# <figure class="rollover">
# <a href="/sites/orano">
# <div class="box-photo">
# <img alt="Orano" class="lazy" data-srcset="https://assets.awwwards.com/awards/media/cache/thumb_417_299/submissions/2018/11/5bf2fbeb71b64.png 1x, https://assets.awwwards.com/awards/media/cache/optimize/submissions/2018/11/5bf2fbeb71b64.png 2x" height="298" src="..." width="417"/>
# </div>
# </a>
# <div class="hover-item top">
# <span class="js-options-collectable"></span>
# <span class="bt-item bt-default bt-likeit js-bt-like js-collect-like">
# ...

# %%
data2 = soup.find_all('data-model')

# %%
print(data2)
# Out:
# []

# %%
from urllib.request import Request, urlopen

urlpage2='https://dribbble.com/shots/popular?timeframe==year'
req = Request(urlpage2, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# %%
print(webpage)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n  <title>\n      Dribbble - Discover the World\xe2\x80\x99s Top Designers & Creative Professionals\n  </title>\n  <meta name="description" content="Dribbble is where designers gain inspiration, feedback, community, and jobs and is your best resource to discover and connect with designers worldwide." />\n  <meta charset="utf-8" />\n  <meta name="theme-color" content="#333333">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0" />\n    <meta name="referrer" content="origin-when-cross-origin">\n  <!--[if gte IE 7]><!-->\n  <link rel="stylesheet" media="screen, projection" href="https://cdn.dribbble.com/assets/master-d6ee434235baf9fd1e44f10385d36895083d8c1a22539097410c89346ee806f5.css" />\n  <link rel="stylesheet" media="screen, projection" href="https://cdn.dribbble.com/assets/home/home-hero-1138be1ef3d16bce21e0086c423e4f4726574fc5d950cff4c10a4d0230c6a20d.css" /><link rel="stylesheet" media="screen" hr
# ...

# %%
webpage = soup.find_all('a', class_='dribbble-link')
webpage
# Out:
# []
